# %% [markdown]
# # SkillMap accuracy-first training
# This notebook calls the repository CLI; it contains no unique training logic or secrets. Review `docs/DATASETS.md` before downloading data.

# %%
import os
import subprocess

subprocess.run(["nvidia-smi"], check=False)
print("CUDA visible:", os.environ.get("CUDA_VISIBLE_DEVICES", "default"))

# %%
# If the repository is not already open in Colab:
# !git clone https://github.com/Deekshith06/SkillMap.git
# %cd /content/SkillMap
# !python -m pip install -r requirements-ml.in -r requirements-dev.in

# %%
# Set SKILLMAP_ESCO_URL through Colab secrets or the environment; never paste API keys here.
# !python -m training.data.download_public
# !python -m training.data.audit
# !python -m training.pipeline --config configs/training/colab.yaml

# %%
# !python -m training.evaluate_all --config configs/training/colab.yaml
# !python -m training.export_runtime --config configs/training/colab.yaml
# !python -m training.validate_runtime
# !tar -czf skillmap-candidate-artifacts.tgz models/candidates/colab reports configs/training/colab.yaml
